# %% [markdown]
# <a href="https://colab.research.google.com/github/LailaBulh/Procesamiento_Lenguaje_Natural/blob/main/Preprocesamiento_normalizacion_texto_LB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Preprocesamiento y normalización de textos**
# **Nombre**: Laila Montserrat Bulhosen Ramos
#
# **Matricula**: 263166
#
# **Link Github:** [Expresiones regulares](https://github.com/LailaBulh/Procesamiento_Lenguaje_Natural/blob/main/Preprocesamiento_normalizacion_texto_LB.ipynb)

# %%
# !pip install emoji
# !pip install pyspellchecker
# !python -m spacy download es_core_news_sm
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.12/dist-packages (2.15.0)
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.12/dist-packages (0.8.4)
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 81.9 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
import spacy
import re
import emoji

# %%
### Carga de archivo CSV
tuits = pd.read_csv('/content/drive/MyDrive/Procesamiento Lenguaje Natural/tuits_cambio_climatico.csv')

print(tuits)
# Out:
#                                                   tuit
# 0    Excelente iniciativa de el uso de energías ren...
# 1    Inspirador que la contaminación plástica afect...
# 2    Datos muestran que los niveles de CO2 disminuy...
# 3    Indignante que las temperaturas globales sigan...
# 4    Inspirador que la deforestación continúe 🌊 #So...
# ..                                                 ...
# 495  Según estudios las temperaturas globales sigan...
# 496  Es alentador ver que se implementen políticas ...
# 497  Se informa que las emisiones de gases efecto i...
# 498  Inaceptable que la contaminación plástica afec...
# 499  Me alegra que las temperaturas globales sigan ...
#
# [500 rows x 1 columns]

# %% [markdown]
# ### **Convertir tuits a minusculas**

# %%
tuits['tuit'] = tuits['tuit'].str.lower()

#print(tuits)

# %% [markdown]
# ### **Eliminar emojis**

# %%
### Se eliminan emojis primero como practica, para que no sean borrados al eliminar puntuaciones

tuits['sin_emojis'] = tuits['tuit'].apply(lambda x: emoji.replace_emoji(x, replace=''))
#print(tuits['sin_emojis'] )

# %% [markdown]
# ### **Eliminar puntuaciones**

# %%
tuits['puntuacion'] = tuits['sin_emojis'].apply(lambda x: re.sub(r'[^\w\s]', '', x))

#print(tuits['puntuacion'])

# %% [markdown]
# ### **Union de tuits en un parrafo**

# %%
all_tuits = ''
c = 0

for row in tuits['puntuacion']:
  all_tuits+= row + ' '
  c +=1

print(all_tuits)
print(f'\n numero de tuits unidos en un parrafo: {c}')
# Out:
# excelente iniciativa de el uso de energías renovables se expanda  medioambiente inspirador que la contaminación plástica afecte los océanos  sostenibilidad datos muestran que los niveles de co2 disminuyan  medioambiente indignante que las temperaturas globales sigan aumentando  ecoconciencia inspirador que la deforestación continúe  sostenibilidad investigación revela que la deforestación continúe  planeta me alegra que las temperaturas globales sigan aumentando  ecoconciencia inaceptable que las temperaturas globales sigan aumentando  cambioclimático datos muestran que los niveles de co2 disminuyan  salvemoselplaneta estadísticas indican que la deforestación continúe  salvemoselplaneta estadísticas indican que la conciencia ambiental crezca  sostenibilidad datos muestran que se implementen políticas verdes  planeta estadísticas indican que el uso de energías renovables se expanda  ecoconciencia me alegra que las temperaturas globales sigan aumentando  planeta investigación revela que la contaminación plástica afecte los océanos  medioambiente datos muestran que la contaminación plástica afecte los océanos  cambioclimático es alentador ver que el uso de energías renovables se expanda  sostenibilidad me alegra que el uso de energías renovables se expanda  planeta increíblemente frustrante que la contaminación plástica afecte los océanos  planeta es preocupante que la contaminación plástica afecte los océanos  cambioclimático es alentador ver que la deforestación continúe  salvemoselplaneta inspirador que las emisiones de gases efecto invernadero no se reduzcan  medioambiente inspirador que las temperaturas globales sigan aumentando  sostenibilidad me alegra que las emisiones de gases efecto invernadero no se reduzcan  sostenibilidad desastroso que el uso de energías renovables se expanda  ecoconciencia desastroso que el uso de energías renovables se expanda  sostenibilidad es preocupante que el uso de energías renovables se expanda  planeta estadísticas indican que los niveles de co2 disminuyan  sostenibilidad datos muestran que los niveles de co2 disminuyan  ecoconciencia qué bueno que el uso de energías renovables se expanda  ecoconciencia datos muestran que la contaminación plástica afecte los océanos  planeta inspirador que las temperaturas globales sigan aumentando  salvemoselplaneta se informa que los niveles de co2 disminuyan  ecoconciencia indignante que el uso de energías renovables se expanda  cambioclimático me alegra que se implementen políticas verdes  ecoconciencia investigación revela que las temperaturas globales sigan aumentando  planeta estadísticas indican que la deforestación continúe  salvemoselplaneta datos muestran que el uso de energías renovables se expanda  salvemoselplaneta se informa que la contaminación plástica afecte los océanos  ecoconciencia es alentador ver que los niveles de co2 disminuyan  cambioclimático datos muestran que las temperaturas globales sigan aumentando  planeta según estudios la deforestación continúe  cambioclimático indignante que las emisiones de gases efecto invernadero no se reduzcan  cambioclimático investigación revela que la deforestación continúe  cambioclimático excelente iniciativa de los niveles de co2 disminuyan  sostenibilidad es alentador ver que las temperaturas globales sigan aumentando  sostenibilidad increíblemente frustrante que la contaminación plástica afecte los océanos  ecoconciencia increíblemente frustrante que las temperaturas globales sigan aumentando  cambioclimático excelente iniciativa de los niveles de co2 disminuyan  salvemoselplaneta investigación revela que los niveles de co2 disminuyan  salvemoselplaneta inspirador que la contaminación plástica afecte los océanos  ecoconciencia me alegra que la deforestación continúe  ecoconciencia inspirador que el uso de energías renovables se expanda  planeta estadísticas indican que las temperaturas globales sigan aumentando  salvemoselplaneta inspirador que la deforestación continúe  cambioclimático inspi ...
#
#  numero de tuits unidos en un parrafo: 500

# %% [markdown]
# ### **Remover stopwords**

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
### Tokenizacion

tokens = word_tokenize(all_tuits, language = 'spanish')
print(f'all_tuits tokenizados: \n{tokens}')

stop_words = set(stopwords.words('spanish'))

tokens_filtrados = [word for word in tokens if word not in stop_words and word.isalpha()]

print(f'\nall_tuits sin stopwords:\n{tokens_filtrados}')
# Out:
# all_tuits tokenizados:
# ['excelente', 'iniciativa', 'de', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'medioambiente', 'inspirador', 'que', 'la', 'contaminación', 'plástica', 'afecte', 'los', 'océanos', 'sostenibilidad', 'datos', 'muestran', 'que', 'los', 'niveles', 'de', 'co2', 'disminuyan', 'medioambiente', 'indignante', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando', 'ecoconciencia', 'inspirador', 'que', 'la', 'deforestación', 'continúe', 'sostenibilidad', 'investigación', 'revela', 'que', 'la', 'deforestación', 'continúe', 'planeta', 'me', 'alegra', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando', 'ecoconciencia', 'inaceptable', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando', 'cambioclimático', 'datos', 'muestran', 'que', 'los', 'niveles', 'de', 'co2', 'disminuyan', 'salvemoselplaneta', 'estadísticas', 'indican', 'que', 'la', 'deforestación', 'continúe', 'salvemoselplaneta', 'estadísticas', 'indican', 'que', 'la', 'conciencia', 'ambiental', 'crezca', 'sostenibilidad', 'datos', 'muestran', 'que', 'se', 'implementen', 'políticas', 'verdes', 'planeta', 'estadísticas', 'indican', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'ecoconciencia', 'me', 'alegra', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando', 'planeta', 'investigación', 'revela', 'que', 'la', 'contaminación', 'plástica', 'afecte', 'los', 'océanos', 'medioambiente', 'datos', 'muestran', 'que', 'la', 'contaminación', 'plástica', 'afecte', 'los', 'océanos', 'cambioclimático', 'es', 'alentador', 'ver', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'sostenibilidad', 'me', 'alegra', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'planeta', 'increíblemente', 'frustrante', 'que', 'la', 'contaminación', 'plástica', 'afecte', 'los', 'océanos', 'planeta', 'es', 'preocupante', 'que', 'la', 'contaminación', 'plástica', 'afecte', 'los', 'océanos', 'cambioclimático', 'es', 'alentador', 'ver', 'que', 'la', 'deforestación', 'continúe', 'salvemoselplaneta', 'inspirador', 'que', 'las', 'emisiones', 'de', 'gases', 'efecto', 'invernadero', 'no', 'se', 'reduzcan', 'medioambiente', 'inspirador', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando', 'sostenibilidad', 'me', 'alegra', 'que', 'las', 'emisiones', 'de', 'gases', 'efecto', 'invernadero', 'no', 'se', 'reduzcan', 'sostenibilidad', 'desastroso', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'ecoconciencia', 'desastroso', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'sostenibilidad', 'es', 'preocupante', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'planeta', 'estadísticas', 'indican', 'que', 'los', 'niveles', 'de', 'co2', 'disminuyan', 'sostenibilidad', 'datos', 'muestran', 'que', 'los', 'niveles', 'de', 'co2', 'disminuyan', 'ecoconciencia', 'qué', 'bueno', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'ecoconciencia', 'datos', 'muestran', 'que', 'la', 'contaminación', 'plástica', 'afecte', 'los', 'océanos', 'planeta', 'inspirador', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando', 'salvemoselplaneta', 'se', 'informa', 'que', 'los', 'niveles', 'de', 'co2', 'disminuyan', 'ecoconciencia', 'indignante', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'cambioclimático', 'me', 'alegra', 'que', 'se', 'implementen', 'políticas', 'verdes', 'ecoconciencia', 'investigación', 'revela', 'que', 'las', 'temperaturas', 'globales', 'sigan', 'aumentando', 'planeta', 'estadísticas', 'indican', 'que', 'la', 'deforestación', 'continúe', 'salvemoselplaneta', 'datos', 'muestran', 'que', 'el', 'uso', 'de', 'energías', 'renovables', 'se', 'expanda', 'salvemoselplaneta', 'se', 'informa', 'que', 'la', 'contaminación', 'plástica', 'afecte', 'los', 'océanos', 'ecoconciencia', 'es', 'alentador', 'ver', 'que', 'los', 'niveles', 'de', 'co2', 'disminuyan', 'cambioclimático', 'datos', 'muestran', ' ...
#
# all_tuits sin stopwords:
# ['excelente', 'iniciativa', 'uso', 'energías', 'renovables', 'expanda', 'medioambiente', 'inspirador', 'contaminación', 'plástica', 'afecte', 'océanos', 'sostenibilidad', 'datos', 'muestran', 'niveles', 'disminuyan', 'medioambiente', 'indignante', 'temperaturas', 'globales', 'sigan', 'aumentando', 'ecoconciencia', 'inspirador', 'deforestación', 'continúe', 'sostenibilidad', 'investigación', 'revela', 'deforestación', 'continúe', 'planeta', 'alegra', 'temperaturas', 'globales', 'sigan', 'aumentando', 'ecoconciencia', 'inaceptable', 'temperaturas', 'globales', 'sigan', 'aumentando', 'cambioclimático', 'datos', 'muestran', 'niveles', 'disminuyan', 'salvemoselplaneta', 'estadísticas', 'indican', 'deforestación', 'continúe', 'salvemoselplaneta', 'estadísticas', 'indican', 'conciencia', 'ambiental', 'crezca', 'sostenibilidad', 'datos', 'muestran', 'implementen', 'políticas', 'verdes', 'planeta', 'estadísticas', 'indican', 'uso', 'energías', 'renovables', 'expanda', 'ecoconciencia', 'alegra', 'temperaturas', 'globales', 'sigan', 'aumentando', 'planeta', 'investigación', 'revela', 'contaminación', 'plástica', 'afecte', 'océanos', 'medioambiente', 'datos', 'muestran', 'contaminación', 'plástica', 'afecte', 'océanos', 'cambioclimático', 'alentador', 'ver', 'uso', 'energías', 'renovables', 'expanda', 'sostenibilidad', 'alegra', 'uso', 'energías', 'renovables', 'expanda', 'planeta', 'increíblemente', 'frustrante', 'contaminación', 'plástica', 'afecte', 'océanos', 'planeta', 'preocupante', 'contaminación', 'plástica', 'afecte', 'océanos', 'cambioclimático', 'alentador', 'ver', 'deforestación', 'continúe', 'salvemoselplaneta', 'inspirador', 'emisiones', 'gases', 'efecto', 'invernadero', 'reduzcan', 'medioambiente', 'inspirador', 'temperaturas', 'globales', 'sigan', 'aumentando', 'sostenibilidad', 'alegra', 'emisiones', 'gases', 'efecto', 'invernadero', 'reduzcan', 'sostenibilidad', 'desastroso', 'uso', 'energías', 'renovables', 'expanda', 'ecoconciencia', 'desastroso', 'uso', 'energías', 'renovables', 'expanda', 'sostenibilidad', 'preocupante', 'uso', 'energías', 'renovables', 'expanda', 'planeta', 'estadísticas', 'indican', 'niveles', 'disminuyan', 'sostenibilidad', 'datos', 'muestran', 'niveles', 'disminuyan', 'ecoconciencia', 'bueno', 'uso', 'energías', 'renovables', 'expanda', 'ecoconciencia', 'datos', 'muestran', 'contaminación', 'plástica', 'afecte', 'océanos', 'planeta', 'inspirador', 'temperaturas', 'globales', 'sigan', 'aumentando', 'salvemoselplaneta', 'informa', 'niveles', 'disminuyan', 'ecoconciencia', 'indignante', 'uso', 'energías', 'renovables', 'expanda', 'cambioclimático', 'alegra', 'implementen', 'políticas', 'verdes', 'ecoconciencia', 'investigación', 'revela', 'temperaturas', 'globales', 'sigan', 'aumentando', 'planeta', 'estadísticas', 'indican', 'deforestación', 'continúe', 'salvemoselplaneta', 'datos', 'muestran', 'uso', 'energías', 'renovables', 'expanda', 'salvemoselplaneta', 'informa', 'contaminación', 'plástica', 'afecte', 'océanos', 'ecoconciencia', 'alentador', 'ver', 'niveles', 'disminuyan', 'cambioclimático', 'datos', 'muestran', 'temperaturas', 'globales', 'sigan', 'aumentando', 'planeta', 'según', 'estudios', 'deforestación', 'continúe', 'cambioclimático', 'indignante', 'emisiones', 'gases', 'efecto', 'invernadero', 'reduzcan', 'cambioclimático', 'investigación', 'revela', 'deforestación', 'continúe', 'cambioclimático', 'excelente', 'iniciativa', 'niveles', 'disminuyan', 'sostenibilidad', 'alentador', 'ver', 'temperaturas', 'globales', 'sigan', 'aumentando', 'sostenibilidad', 'increíblemente', 'frustrante', 'contaminación', 'plástica', 'afecte', 'océanos', 'ecoconciencia', 'increíblemente', 'frustrante', 'temperaturas', 'globales', 'sigan', 'aumentando', 'cambioclimático', 'excelente', 'iniciativa', 'niveles', 'disminuyan', 'salvemoselplaneta', 'investigación', 'revela', 'niveles', 'disminuyan', 'salvemoselplaneta', 'inspirador', 'contaminación', 'plástica', 'afecte', 'océanos', 'ecoconciencia', 'alegra', 'd ...

# %%
### Contar frecuencia de palabras
from collections import Counter

frecuencia = Counter(tokens_filtrados)
print(frecuencia)
# Out:
# Counter({'ecoconciencia': 93, 'salvemoselplaneta': 91, 'planeta': 84, 'cambioclimático': 82, 'medioambiente': 78, 'emisiones': 78, 'gases': 78, 'efecto': 78, 'invernadero': 78, 'reduzcan': 78, 'uso': 72, 'energías': 72, 'renovables': 72, 'expanda': 72, 'sostenibilidad': 72, 'temperaturas': 67, 'globales': 67, 'sigan': 67, 'aumentando': 67, 'contaminación': 62, 'plástica': 62, 'afecte': 62, 'océanos': 62, 'niveles': 61, 'disminuyan': 61, 'deforestación': 59, 'continúe': 59, 'conciencia': 58, 'ambiental': 58, 'crezca': 58, 'datos': 45, 'muestran': 45, 'inspirador': 44, 'implementen': 43, 'políticas': 43, 'verdes': 43, 'indignante': 39, 'alentador': 39, 'ver': 39, 'alegra': 36, 'inaceptable': 34, 'desastroso': 33, 'excelente': 32, 'iniciativa': 32, 'estadísticas': 30, 'indican': 30, 'increíblemente': 30, 'frustrante': 30, 'preocupante': 30, 'según': 30, 'estudios': 30, 'investigación': 28, 'revela': 28, 'informa': 27, 'bueno': 23})

# %% [markdown]
# ### **Gráfica de top 20 de palabras más frecuentes**

# %%
### Grafica de las 20 palabras más frecuentes

from matplotlib import pyplot as plt

data = dict(frecuencia.most_common(20))
data = pd.Series(data)
ax = data.plot.bar()

# %%
counts = Counter({'Action': 303, 'Adventure': 259, 'Sci-Fi': 120, 'Mystery': 106, 'Horror': 119, 'Thriller': 195, 'Animation': 49, 'Comedy': 279, 'Family': 51, 'Fantasy': 101, 'Drama': 513, 'Music': 16, 'Biography': 81, 'Romance': 141, 'History': 29, 'Crime': 150, 'Western': 7, 'War': 13, 'Musical': 5, 'Sport': 18})
data = pd.Series(counts)
ax = data.plot.bar()
ax.set(xlabel='Genre', ylabel='Count', title='Good luck on your BS')

# %% [markdown]
# ### **Nube de palabras**

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from wordcloud import WordCloud

# %%
### Nube de palabras

plt.figure(figsize= (12,6))

wourdcloud_raw = WordCloud(width= 1000, height= 500, background_color= 'white', collocations= False).generate(frecuencia)
plt.imshow(wourdcloud_raw, interpolation= 'bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1694712960.py in <cell line: 0>()
#       3 plt.figure(figsize= (12,6))
#       4
# ----> 5 wourdcloud_raw = WordCloud(width= 1000, height= 500, background_color= 'white', collocations= False).generate(frecuencia)
#       6 plt.imshow(wourdcloud_raw, interpolation= 'bilinear')
#       7 plt.axis('off')
#
# /usr/local/lib/python3.12/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     641         self
#     642         """
# --> 643         return self.generate_from_text(text)
#     644
#     645     def _check_generated(self):
#
# /usr/local/lib/python3.12/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     622         self
#     623         """
# --> 624         words = self.process_text(text)
#     625         self.generate_from_frequencies(words)
#     626         return self
#
# /usr/local/lib/python3.12/dist-packages/wordcloud/wordcloud.py in process_text(self, text)
#     584         regexp = self.regexp if self.regexp is not None else pattern
#     585
# --> 586         words = re.findall(regexp, text, flags)
#     587         # remove 's
#     588         words = [word[:-2] if word.lower().endswith("'s") else word
#
# /usr/lib/python3.12/re/__init__.py in findall(pattern, string, flags)
#     215
#     216     Empty matches are included in the result."""
# --> 217     return _compile(pattern, flags).findall(string)
#     218
#     219 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object, got 'Counter'
